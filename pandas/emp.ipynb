# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('emp.csv')
df
# Out:
#    EmployeeID EmployeeName  DepartmentID
# 0           1        Alice         101.0
# 1           2          Bob         102.0
# 2           3      Charlie         103.0
# 3           4         Alex           NaN
# 4           5       Stella         101.0
# 5           6          Ava         102.0

# %%
df1=pd.read_csv('dept.csv')
df1
# Out:
#    DepartmentID DepartmentName  LocationID
# 0           101             HR         201
# 1           102    Engineering         202
# 2           103      Marketing         203
# 3           104             IT         204

# %%
# to join two tables
df.merge(df1,on='DepartmentID')
# Out:
#    EmployeeID EmployeeName  DepartmentID DepartmentName  LocationID
# 0           1        Alice         101.0             HR         201
# 1           2          Bob         102.0    Engineering         202
# 2           3      Charlie         103.0      Marketing         203
# 3           5       Stella         101.0             HR         201
# 4           6          Ava         102.0    Engineering         202

# %%
df.merge(df1,how='outer')
# Out:
#    EmployeeID EmployeeName  DepartmentID DepartmentName  LocationID
# 0         1.0        Alice         101.0             HR       201.0
# 1         5.0       Stella         101.0             HR       201.0
# 2         2.0          Bob         102.0    Engineering       202.0
# 3         6.0          Ava         102.0    Engineering       202.0
# 4         3.0      Charlie         103.0      Marketing       203.0
# 5         NaN          NaN         104.0             IT       204.0
# 6         4.0         Alex           NaN            NaN         NaN

# %%
df.merge(df1,on='DepartmentID',how='left')
# Out:
#    EmployeeID EmployeeName  DepartmentID DepartmentName  LocationID
# 0           1        Alice         101.0             HR       201.0
# 1           2          Bob         102.0    Engineering       202.0
# 2           3      Charlie         103.0      Marketing       203.0
# 3           4         Alex           NaN            NaN         NaN
# 4           5       Stella         101.0             HR       201.0
# 5           6          Ava         102.0    Engineering       202.0

# %%
df.merge(df1,how='cross',suffixes=('_left','_right'))
# Out:
#     EmployeeID EmployeeName  DepartmentID_left  DepartmentID_right  \
# 0            1        Alice              101.0                 101
# 1            1        Alice              101.0                 102
# 2            1        Alice              101.0                 103
# 3            1        Alice              101.0                 104
# 4            2          Bob              102.0                 101
# 5            2          Bob              102.0                 102
# 6            2          Bob              102.0                 103
# 7            2          Bob              102.0                 104
# 8            3      Charlie              103.0                 101
# 9            3      Charlie              103.0                 102
# 10           3      Charlie              103.0                 103
# 11           3      Charlie              103.0                 104
# 12           4         Alex                NaN                 101
# ...

# %%
#Merge syntax
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
#          left_index=False, right_index=False, sort=False,
#          suffixes=('_x', '_y'), copy=True, indicator=False,
#          validate=None)

# %%
pd.merge(df,df1,on='DepartmentID',how='outer',indicator=True)
# Out:
#    EmployeeID EmployeeName  DepartmentID DepartmentName  LocationID  \
# 0         1.0        Alice         101.0             HR       201.0
# 1         5.0       Stella         101.0             HR       201.0
# 2         2.0          Bob         102.0    Engineering       202.0
# 3         6.0          Ava         102.0    Engineering       202.0
# 4         3.0      Charlie         103.0      Marketing       203.0
# 5         NaN          NaN         104.0             IT       204.0
# 6         4.0         Alex           NaN            NaN         NaN
#
#        _merge
# 0        both
# 1        both
# 2        both
# 3        both
# 4        both
# 5  right_only
# 6   left_only

# %%
df2=pd.read_csv('salary.csv')
df2
# Out:
#    EmployeeID  AnnualSalary
# 0           1       60000.0
# 1           2       80000.0
# 2           3       75000.0

# %%
# to merge 3 tables
j1=df.merge(df1)
j2=j1.merge(df2)
j2
# Out:
#    EmployeeID EmployeeName  DepartmentID DepartmentName  LocationID  \
# 0           1        Alice         101.0             HR         201
# 1           2          Bob         102.0    Engineering         202
# 2           3      Charlie         103.0      Marketing         203
#
#    AnnualSalary
# 0       60000.0
# 1       80000.0
# 2       75000.0
