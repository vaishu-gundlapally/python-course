# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Population.csv")
data
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Rank                         234 non-null    int64
#  1   CCA3                         234 non-null    object
#  2   Country                      234 non-null    object
#  3   Capital                      234 non-null    object
#  4   Continent                    234 non-null    object
#  5   2022 Population              230 non-null    float64
#  6   2020 Population              233 non-null    float64
#  7   2015 Population              230 non-null    float64
#  8   2010 Population              227 non-null    float64
#  9   2000 Population              227 non-null    float64
#  10  1990 Population              229 non-null    float64
#  11  1980 Population              229 non-null    float64
# ...

# %%
data[data["Rank"]<=10]
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 27      7  BRA         Brazil          Brasilia  South America
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 131    10  MEX         Mexico       Mexico City  North America
# 149     6  NGA        Nigeria             Abuja         Africa
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# 27      2.153135e+08     2.131963e+08     2.051882e+08     1.963535e+08
# ...

# %%
data[data['Country'].isin(['India','China'])]
# Out:
#     Rank CCA3 Country    Capital Continent  2022 Population  2020 Population  \
# 41     1  CHN   China    Beijing      Asia     1.425887e+09     1.424930e+09
# 92     2  IND   India  New Delhi      Asia     1.417173e+09     1.396387e+09
#
#     2015 Population  2010 Population  2000 Population  1990 Population  \
# 41     1.393715e+09     1.348191e+09     1.264099e+09     1.153704e+09
# 92     1.322867e+09     1.240614e+09     1.059634e+09              NaN
#
#     1980 Population  1970 Population  Area (km²)  Density (per km²)  \
# 41      982372466.0      822534450.0   9706961.0           146.8933
# 92              NaN      557501301.0   3287590.0           431.0675
#
#     Growth Rate  World Population Percentage
# 41       1.0000                        17.88
# 92       1.0068                        17.77

# %%
data[data['Country'].str.contains("United")]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
#no case sensitive
data[data['Country'].str.contains("united",case=False)]
# Out:
#      Rank CCA3                       Country           Capital      Continent  \
# 219    97  ARE          United Arab Emirates         Abu Dhabi           Asia
# 220    21  GBR                United Kingdom            London         Europe
# 221     3  USA                 United States  Washington, D.C.  North America
# 222   200  VIR  United States Virgin Islands  Charlotte Amalie  North America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 219        9441129.0        9287289.0        8916899.0        8481771.0
# 220       67508936.0       67059474.0       65224364.0       62760039.0
# 221      338289857.0      335942003.0      324607776.0      311182845.0
# 222          99465.0         100442.0         102803.0         106142.0
#
#      2000 Population  1990 Population  1980 Population  1970 Population  \
# 219        3275333.0        1900151.0        1014048.0         298084.0
# ...

# %%
data
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
data.set_index('Rank')
# Out:
#      CCA3            Country           Capital Continent  2022 Population  \
# Rank
# 36    AFG        Afghanistan             Kabul      Asia       41128771.0
# 138   ALB            Albania            Tirana    Europe        2842321.0
# 34    DZA            Algeria           Algiers    Africa       44903225.0
# 213   ASM     American Samoa         Pago Pago   Oceania          44273.0
# 203   AND            Andorra  Andorra la Vella    Europe          79824.0
# ...   ...                ...               ...       ...              ...
# 226   WLF  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# 172   ESH     Western Sahara          El Aaiún    Africa         575986.0
# 46    YEM              Yemen             Sanaa      Asia       33696614.0
# 63    ZMB             Zambia            Lusaka    Africa       20017675.0
# 74    ZWE           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
data.filter(items=["Rank","Capital"],axis=1)
# Out:
#      Rank           Capital
# 0      36             Kabul
# 1     138            Tirana
# 2      34           Algiers
# 3     213         Pago Pago
# 4     203  Andorra la Vella
# ..    ...               ...
# 229   226          Mata-Utu
# 230   172          El Aaiún
# 231    46             Sanaa
# 232    63            Lusaka
# 233    74            Harare
#
# [234 rows x 2 columns]

# %%
data.iloc[1:10]
# Out:
#    Rank CCA3              Country           Capital      Continent  \
# 1   138  ALB              Albania            Tirana         Europe
# 2    34  DZA              Algeria           Algiers         Africa
# 3   213  ASM       American Samoa         Pago Pago        Oceania
# 4   203  AND              Andorra  Andorra la Vella         Europe
# 5    42  AGO               Angola            Luanda         Africa
# 6   224  AIA             Anguilla        The Valley  North America
# 7   201  ATG  Antigua and Barbuda      Saint John’s  North America
# 8    33  ARG            Argentina      Buenos Aires  South America
# 9   140  ARM              Armenia           Yerevan           Asia
#
#    2022 Population  2020 Population  2015 Population  2010 Population  \
# 1        2842321.0        2866849.0        2882481.0        2913399.0
# 2       44903225.0       43451666.0       39543154.0       35856344.0
# 3          44273.0          46189.0          51368.0          54849.0
# ...

# %%
data[data['Rank']<=10].sort_values(by=['Continent'],ascending=True)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 149     6  NGA        Nigeria             Abuja         Africa
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 131    10  MEX         Mexico       Mexico City  North America
# 221     3  USA  United States  Washington, D.C.  North America
# 27      7  BRA         Brazil          Brasilia  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# 16      1.711864e+08     1.674210e+08     1.578300e+08     1.483911e+08
# ...

# %%
data[data['Rank']<=10].sort_values(by=['Continent','Capital'],ascending=[True,False])
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 149     6  NGA        Nigeria             Abuja         Africa
# 92      2  IND          India         New Delhi           Asia
# 93      4  IDN      Indonesia           Jakarta           Asia
# 156     5  PAK       Pakistan         Islamabad           Asia
# 16      8  BGD     Bangladesh             Dhaka           Asia
# 41      1  CHN          China           Beijing           Asia
# 171     9  RUS         Russia            Moscow         Europe
# 221     3  USA  United States  Washington, D.C.  North America
# 131    10  MEX         Mexico       Mexico City  North America
# 27      7  BRA         Brazil          Brasilia  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 149     2.185412e+08     2.083274e+08     1.839958e+08     1.609529e+08
# 92      1.417173e+09     1.396387e+09     1.322867e+09     1.240614e+09
# ...

# %%
data
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
# to reset the indext to original indexes
data.reset_index(inplace=True)
data
# Out:
#      index  Rank CCA3            Country           Capital Continent  \
# 0        0    36  AFG        Afghanistan             Kabul      Asia
# 1        1   138  ALB            Albania            Tirana    Europe
# 2        2    34  DZA            Algeria           Algiers    Africa
# 3        3   213  ASM     American Samoa         Pago Pago   Oceania
# 4        4   203  AND            Andorra  Andorra la Vella    Europe
# ..     ...   ...  ...                ...               ...       ...
# 229    229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230    230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    231    46  YEM              Yemen             Sanaa      Asia
# 232    232    63  ZMB             Zambia            Lusaka    Africa
# 233    233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
# we can group 2 or more columns to set as index
data.set_index(['Continent','Country'],inplace=True)
data
# Out:
#                              index  Rank CCA3           Capital  \
# Continent Country
# Asia      Afghanistan            0    36  AFG             Kabul
# Europe    Albania                1   138  ALB            Tirana
# Africa    Algeria                2    34  DZA           Algiers
# Oceania   American Samoa         3   213  ASM         Pago Pago
# Europe    Andorra                4   203  AND  Andorra la Vella
# ...                            ...   ...  ...               ...
# Oceania   Wallis and Futuna    229   226  WLF          Mata-Utu
# Africa    Western Sahara       230   172  ESH          El Aaiún
# Asia      Yemen                231    46  YEM             Sanaa
# Africa    Zambia               232    63  ZMB            Lusaka
#           Zimbabwe             233    74  ZWE            Harare
#
#                              2022 Population  2020 Population  \
# Continent Country
# Asia      Afghanistan             41128771.0       38972230.0
# ...

# %%
# to retrieve data using loc having continent=Asia
data.loc[['Asia']]
# Out:
#                                 index  Rank CCA3              Capital  \
# Continent Country
# Asia      Afghanistan               0    36  AFG                Kabul
#           Armenia                   9   140  ARM              Yerevan
#           Azerbaijan               13    91  AZE                 Baku
#           Bahrain                  15   154  BHR               Manama
#           Bangladesh               16     8  BGD                Dhaka
#           Bhutan                   23   165  BTN              Thimphu
#           Brunei                   29   175  BRN  Bandar Seri Begawan
#           Cambodia                 33    73  KHM           Phnom Penh
#           China                    41     1  CHN              Beijing
#           Georgia                  73   131  GEO              Tbilisi
#           Hong Kong                89   104  HKG            Hong Kong
#           India                    92     2  IND            New Delhi
# ...

# %%
# using iloc in the backend it is stores as indexes so we can retrieve using indexes 
data.iloc[10:20]
# Out:
#                           index  Rank CCA3     Capital  2022 Population  \
# Continent     Country
# North America Aruba          10   198  ABW  Oranjestad         106445.0
# Oceania       Australia      11    55  AUS    Canberra       26177413.0
# Europe        Austria        12    99  AUT      Vienna        8939617.0
# Asia          Azerbaijan     13    91  AZE        Baku       10358074.0
# North America Bahamas        14   176  BHS      Nassau         409984.0
# Asia          Bahrain        15   154  BHR      Manama        1472233.0
#               Bangladesh     16     8  BGD       Dhaka      171186372.0
# North America Barbados       17   186  BRB  Bridgetown         281635.0
# Europe        Belarus        18    96  BLR       Minsk        9534954.0
#               Belgium        19    81  BEL    Brussels       11655930.0
#
#                           2020 Population  2015 Population  2010 Population  \
# Continent     Country
# ...

# %%
# to retrieve particular record using index as we set index as country
data.loc['Asia','India']
# Out:
# index                                    92
# Rank                                      2
# CCA3                                    IND
# Capital                           New Delhi
# 2022 Population                1417173173.0
# 2020 Population                1396387127.0
# 2015 Population                1322866505.0
# 2010 Population                1240613620.0
# 2000 Population                1059633675.0
# 1990 Population                         NaN
# 1980 Population                         NaN
# 1970 Population                 557501301.0
# Area (km²)                        3287590.0
# Density (per km²)                  431.0675
# Growth Rate                          1.0068
# World Population Percentage           17.77
# Name: (Asia, India), dtype: object

# %%
# to sort the continent like in asia continent i need countries present inside them
data.sort_index()
# Out:
#                             index  Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria           2    34  DZA      Algiers       44903225.0
#               Angola            5    42  AGO       Luanda       35588987.0
#               Benin            21    77  BEN   Porto-Novo       13352864.0
#               Botswana         26   144  BWA     Gaborone        2630296.0
#               Burkina Faso     31    58  BFA  Ouagadougou       22673762.0
# ...                           ...   ...  ...          ...              ...
# South America Paraguay        161   109  PRY     Asunción        6780744.0
#               Peru            162    44  PER         Lima       34049588.0
#               Suriname        199   170  SUR   Paramaribo         618040.0
#               Uruguay         223   133  URY   Montevideo        3422794.0
#               Venezuela       227    51  VEN      Caracas       28301696.0
#
# ...

# %%
#to retrieve data from specific continent and countries, we specify the names and after the comma we give colon becuase we want all the columns
data.loc[(['Asia','South America'],['India','China','Suriname','Peru']),:]
# if we want only certain columns we specifiy the column names
data.loc[(['Asia','South America'],['India','China','Suriname','Peru']),['index','Rank']]
# Out:
#                         index  Rank
# Continent     Country
# Asia          India        92     2
#               China        41     1
# South America Suriname    199   170
#               Peru        162    44

# %%
# all the rows of specific columns
data.loc[:,['index','Rank']]
# Out:
#                              index  Rank
# Continent Country
# Asia      Afghanistan            0    36
# Europe    Albania                1   138
# Africa    Algeria                2    34
# Oceania   American Samoa         3   213
# Europe    Andorra                4   203
# ...                            ...   ...
# Oceania   Wallis and Futuna    229   226
# Africa    Western Sahara       230   172
# Asia      Yemen                231    46
# Africa    Zambia               232    63
#           Zimbabwe             233    74
#
# [234 rows x 2 columns]
